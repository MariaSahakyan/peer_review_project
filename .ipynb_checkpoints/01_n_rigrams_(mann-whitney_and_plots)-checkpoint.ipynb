# %%
from scipy.stats import mannwhitneyu
from pathlib import Path
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

DATA_DIR = Path("data")  
FIG_DIR = Path("figures")
FIG_DIR.mkdir(exist_ok=True)

# %%
df = pd.read_csv(DATA_DIR / "anonymized_data.csv")

# %%
# ---- settings ----
iterations = 1000 
TONE_COLS = ['Appreciation', 'Constructiveness', 'Clarifications', 'Critique']
CONFOUNDERS = {
    'gender':   ['Male', 'Female'],
    'race':     ['White', 'NonWhite'],
    'region':   ['Western', 'Eastern'],
    'uni_rank': ['Top100', 'Other'],
}

def calculate_rbc(u_stat: float, n1: int, n2: int) -> float:
    # Rank-biserial correlation from Mann–Whitney U
    return (2 * u_stat) / (n1 * n2) - 1

def bootstrap_rbc(group1: np.ndarray,
                  group2: np.ndarray,
                  n_iter: int = iterations,
                  seed: int = 42) -> tuple[float, float]:
    rng = np.random.default_rng(seed)
    n1, n2 = len(group1), len(group2)
    if n1 < 2 or n2 < 2:
        return (np.nan, np.nan)

    rbcs = []
    for _ in range(n_iter):
        s1 = rng.choice(group1, size=n1, replace=True)
        s2 = rng.choice(group2, size=n2, replace=True)
        try:
            u, _ = mannwhitneyu(s1, s2, alternative='two-sided')
            rbcs.append(calculate_rbc(u, n1, n2))
        except ValueError:
            pass

    if len(rbcs) >= max(30, n_iter // 10):
        lo, hi = np.percentile(rbcs, [2.5, 97.5])
        return (float(lo), float(hi))
    return (np.nan, np.nan)

def p_to_stars(p):
    if pd.isna(p): return ''
    if p < 0.001: return '***'
    if p < 0.01:  return '**'
    if p < 0.05:  return '*'
    return ''

def _subset_for_identity(df, identity_label: str):
    """Return the slice of df to analyze for the given identity."""
    base = df[df['word_count'] > 5]
    if identity_label == 'Disclosed':
        return base[base['disclosed_reviewer'] == 1]
    if identity_label == 'Undisclosed':
        return base[base['disclosed_reviewer'] == 0]
    #identity_label == 'All' → full dataset 
    return base

def run_hypothesis_tests(df: pd.DataFrame,
                         tone_cols=TONE_COLS,
                         confounders=CONFOUNDERS,
                         n_boot: int = iterations,
                         seed: int = 42) -> pd.DataFrame:
    # ensure numeric
    for c in tone_cols:
        df[c] = pd.to_numeric(df[c], errors='coerce')

    out = []
    for identity_label in ['Disclosed', 'Undisclosed', 'All']:
        subset = _subset_for_identity(df, identity_label)

        for conf_name, (g1, g2) in confounders.items():
            s1 = subset[subset[conf_name] == g1]
            s2 = subset[subset[conf_name] == g2]

            for tone in tone_cols:
                v1 = s1[tone].dropna().values
                v2 = s2[tone].dropna().values
                n1, n2 = len(v1), len(v2)

                u = p = rbc = ci_lo = ci_hi = np.nan
                if n1 > 1 and n2 > 1:
                    try:
                        u, p = mannwhitneyu(v1, v2, alternative='two-sided')
                        rbc = calculate_rbc(u, n1, n2)
                        ci_lo, ci_hi = bootstrap_rbc(v1, v2, n_iter=n_boot, seed=seed)
                    except ValueError:
                        pass

                mean1 = np.mean(v1) if n1 else np.nan
                mean2 = np.mean(v2) if n2 else np.nan
                se1   = (np.std(v1, ddof=1) / np.sqrt(n1)) if n1 > 1 else np.nan
                se2   = (np.std(v2, ddof=1) / np.sqrt(n2)) if n2 > 1 else np.nan
                higher = '' if (pd.isna(mean1) or pd.isna(mean2)) else (g1 if mean1 > mean2 else g2 if mean2 > mean1 else 'Equal')

                out.append({
                    'Tone Category': tone,
                    'Reviewer Identity': identity_label,
                    'Confounder': conf_name,
                    'Group 1': g1, 'Group 2': g2,
                    'Group 1 Mean': mean1, 'Group 2 Mean': mean2,
                    'Group 1 Size': n1, 'Group 2 Size': n2,
                    'Group 1 SE': se1, 'Group 2 SE': se2,
                    'U-statistic': u, 'P-value': p,
                    'Effect Size (RBC)': rbc,
                    'Effect Size CI Lower': ci_lo,
                    'Effect Size CI Upper': ci_hi,
                    'Significance': p_to_stars(p),
                    'Higher Group': higher,
                })

    res = pd.DataFrame(out)
    cols = ['Tone Category','Reviewer Identity','Confounder','Group 1','Group 2',
            'Group 1 Mean','Group 1 SE','Group 1 Size',
            'Group 2 Mean','Group 2 SE','Group 2 Size',
            'U-statistic','P-value','Significance',
            'Effect Size (RBC)','Effect Size CI Lower','Effect Size CI Upper',
            'Higher Group']
    return res[cols]

# %%
# ---- run & save ----
results_ttest = run_hypothesis_tests(df, n_boot=iterations, seed=42)
RESULTS_DIR = Path("results")
RESULTS_DIR.mkdir(exist_ok=True)
out_csv = RESULTS_DIR / "mannwhitney_rbc_results.csv"
results_ttest.to_csv(out_csv, index=False)
results_ttest.to_parquet(RESULTS_DIR / "mannwhitney_rbc_results.parquet", index=False)
print(f"Saved: {out_csv.resolve()}")
# Out:
# Saved: C:\Users\ms13502\peer_review_project\results\mannwhitney_rbc_results.csv

# %%
results_ttest
# Out:
#        Tone Category Reviewer Identity Confounder  Group 1   Group 2  \
# 0       Appreciation         Disclosed     gender     Male    Female
# 1   Constructiveness         Disclosed     gender     Male    Female
# 2     Clarifications         Disclosed     gender     Male    Female
# 3           Critique         Disclosed     gender     Male    Female
# 4       Appreciation         Disclosed       race    White  NonWhite
# 5   Constructiveness         Disclosed       race    White  NonWhite
# 6     Clarifications         Disclosed       race    White  NonWhite
# 7           Critique         Disclosed       race    White  NonWhite
# 8       Appreciation         Disclosed     region  Western   Eastern
# 9   Constructiveness         Disclosed     region  Western   Eastern
# 10    Clarifications         Disclosed     region  Western   Eastern
# 11          Critique         Disclosed     region  Western   Eastern
# 12      Appreciation         Disclosed   uni_rank   Top100     Other
# 13  Constructiveness         Disclosed   uni_rank   Top100     Other
# 14    Clarifications         Disclosed   uni_rank   Top100     Other
# 15          Critique         Disclosed   uni_rank   Top100     Other
# 16      Appreciation       Undisclosed     gender     Male    Female
# 17  Constructiveness       Undisclosed     gender     Male    Female
# 18    Clarifications       Undisclosed     gender     Male    Female
# 19          Critique       Undisclosed     gender     Male    Female
# 20      Appreciation       Undisclosed       race    White  NonWhite
# 21  Constructiveness       Undisclosed       race    White  NonWhite
# 22    Clarifications       Undisclosed       race    White  NonWhite
# 23          Critique       Undisclosed       race    White  NonWhite
# 24      Appreciation       Undisclosed     region  Western   Eastern
# 25  Constructiveness       Undisclosed     region  Western   Eastern
# 26    Clarifications       Undisclosed     region  Western   Eastern
# 27          Critique       Undisclosed     region  Western   Eastern
# 28      Appreciation       Undisclosed   uni_rank   Top100     Other
# 29  Constructiveness       Undisclosed   uni_rank   Top100     Other
# 30    Clarifications       Undisclosed   uni_rank   Top100     Other
# 31          Critique       Undisclosed   uni_rank   Top100     Other
# 32      Appreciation               All     gender     Male    Female
# 33  Constructiveness               All     gender     Male    Female
# 34    Clarifications               All     gender     Male    Female
# 35          Critique               All     gender     Male    Female
# 36      Appreciation               All       race    White  NonWhite
# 37  Constructiveness               All       race    White  NonWhite
# 38    Clarifications               All       race    White  NonWhite
# 39          Critique               All       race    White  NonWhite
# 40      Appreciation               All     region  Western   Eastern
# 41  Constructiveness               All     region  Western   Eastern
# 42    Clarifications               All     region  Western   Eastern
# 43          Critique               All     region  Western   Eastern
# 44      Appreciation               All   uni_rank   Top100     Other
# 45  Constructiveness               All   uni_rank   Top100     Other
# 46    Clarifications               All   uni_rank   Top100     Other
# 47          Critique               All   uni_rank   Top100     Other
#
#     Group 1 Mean  Group 1 SE  Group 1 Size  Group 2 Mean  Group 2 SE  \
# 0       3.205395    0.083552         10520      3.698048    0.131461
# 1       2.864978    0.060870         10520      2.833130    0.081434
# 2       3.315012    0.059077         10520      3.307963    0.078389
# 3       1.589307    0.040726         10520      1.633452    0.059978
# 4       3.585966    0.115283          6474      3.247563    0.090798
# 5       2.695503    0.072815          6474      2.957048    0.065060
# 6       3.170904    0.071674          6474      3.405141    0.062375
# 7       1.502051    0.049390          6474      1.672494    0.045677
# 8       3.450891    0.096295          9224      3.293878    0.106287
# 9       2.682330    0.060830          9224      3.076262    0.079427
# 10      3.198019    0.059301          9224      3.461756    0.076344
# 11      1.484521    0.041110          9224      1.761803    0.056478
# 12      3.324754    0.139381          4069      3.400156    0.083031
# 13      2.647928    0.092410          4069      2.921644    0.057217
# 14      3.093909    0.086783          4069      3.384810    0.055827
# 15      1.502205    0.065441          4069      1.639114    0.039468
# 16      2.418700    0.033769         43289      2.879687    0.054227
# 17      2.795368    0.028014         43289      2.962181    0.043552
# 18      3.430744    0.028248         43289      3.623356    0.042353
# 19      1.708695    0.020484         43289      1.803084    0.031316
# 20      2.718345    0.045129         26402      2.458455    0.037379
# 21      2.630922    0.033873         26402      3.003100    0.032388
# 22      3.436605    0.034571         26402      3.531912    0.031836
# 23      1.658079    0.025794         26402      1.796171    0.022921
# 24      2.659045    0.035871         39609      2.417787    0.048352
# 25      2.618708    0.027250         39609      3.234453    0.043546
# 26      3.408553    0.028160         39609      3.632861    0.041593
# 27      1.661771    0.020499         39609      1.869657    0.030502
# 28      2.393375    0.046248         20910      2.650775    0.036420
# 29      2.542471    0.036086         20910      2.998551    0.030372
# 30      3.295014    0.036367         20910      3.588918    0.030145
# 31      1.570794    0.025805         20910      1.821122    0.022208
# 32      2.572504    0.031728         53809      3.062190    0.051371
# 33      2.808977    0.025486         53809      2.933402    0.038405
# 34      3.408117    0.025493         53809      3.553020    0.037271
# 35      1.685354    0.018303         53809      1.765254    0.027769
# 36      2.889199    0.042807         32876      2.624021    0.035178
# 37      2.643640    0.030750         32876      2.993438    0.029005
# 38      3.384282    0.031150         32876      3.505314    0.028358
# 39      1.627354    0.022886         32876      1.770222    0.020492
# 40      2.808615    0.034341         48833      2.619018    0.044582
# 41      2.630725    0.024911         48833      3.198118    0.038186
# 42      3.368786    0.025442         48833      3.593560    0.036526
# 43      1.628290    0.018353         48833      1.844884    0.026840
# 44      2.545093    0.044932         24979      2.818189    0.033849
# 45      2.559649    0.033751         24979      2.981370    0.026828
# 46      3.262254    0.033568         24979      3.543320    0.026528
# 47      1.559621    0.024088         24979      1.780460    0.019372
#
#     Group 2 Size  U-statistic        P-value Significance  Effect Size (RBC)  \
# 0           5848   29860306.0   1.275553e-04          ***          -0.029264
# 1           5848   30869377.0   6.541468e-01                        0.003540
# 2           5848   30767678.0   9.776082e-01                        0.000234
# 3           5848   30792692.0   8.827440e-01                        0.001047
# 4           9894   33985784.0   3.068779e-16          ***           0.061164
# 5           9894   32016156.0   9.655196e-01                       -0.000335
# 6           9894   32059687.5   9.002165e-01                        0.001024
# 7           9894   32165344.0   5.343684e-01                        0.004323
# 8           7137   35285326.0   1.819157e-22          ***           0.071986
# 9           7137   33069748.5   5.403748e-01                        0.004676
# 10          7137   33573470.0   1.314294e-02            *           0.019979
# 11          7137   33094971.5   4.277322e-01                        0.005442
# 12         12299   25845665.0   1.022298e-04          ***           0.032905
# 13         12299   25065676.5   8.432110e-01                        0.001733
# 14         12299   25075081.0   8.195371e-01                        0.002109
# 15         12299   24996653.5   8.963464e-01                       -0.001026
# 16         20375  427125053.0   2.865381e-16          ***          -0.031477
# 17         20375  437235147.5   4.190854e-02            *          -0.008552
# 18         20375  432397351.0   1.176595e-05          ***          -0.019522
# 19         20375  438731030.0   1.837416e-01                       -0.005160
# 20         37262  515715509.0   2.697857e-40          ***           0.048425
# 21         37262  485667633.0   1.467806e-03           **          -0.012661
# 22         37262  500252623.0   5.639587e-05          ***           0.016989
# 23         37262  495779303.5   3.170808e-02            *           0.007895
# 24         23935  509795656.5   4.591978e-92          ***           0.075471
# 25         23935  468162066.0   2.280444e-03           **          -0.012359
# 26         23935  485969296.5   4.322709e-09          ***           0.025207
# 27         23935  482748725.5   8.553338e-07          ***           0.018413
# 28         42754  453451338.5   1.571097e-04          ***           0.014448
# 29         42754  444458182.0   1.744095e-01                       -0.005671
# 30         42754  450333603.0   9.125737e-02                        0.007473
# 31         42754  448028671.0   5.479197e-01                        0.002317
# 32         26223  682990160.0   1.513595e-20          ***          -0.031929
# 33         26223  701715297.5   1.465205e-01                       -0.005388
# 34         26223  695476589.5   2.934862e-04          ***          -0.014231
# 35         26223  703540213.0   4.112732e-01                       -0.002801
# 36         47156  814390429.5   8.523346e-54          ***           0.050623
# 37         47156  767516710.0   5.409331e-03           **          -0.009848
# 38         47156  786113361.5   1.619018e-04          ***           0.014143
# 39         47156  781052026.0   1.925129e-02            *           0.007614
# 40         31072  814224803.0  2.170964e-108          ***           0.073227
# 41         31072  752672782.5   2.707134e-02            *          -0.007904
# 42         31072  778018214.0   1.642526e-11          ***           0.025503
# 43         31072  771582020.5   2.211551e-07          ***           0.017020
# 44         55053  698344805.5   6.921782e-06          ***           0.015650
# 45         55053  685461035.0   4.113415e-01                       -0.003088
# 46         55053  693557405.0   2.910457e-02            *           0.008687
# 47         55053  690236839.5   2.640266e-01                        0.003858
#
#     Effect Size CI Lower  Effect Size CI Upper Higher Group
# 0                    NaN                   NaN       Female
# 1                    NaN                   NaN         Male
# 2                    NaN                   NaN         Male
# 3                    NaN                   NaN       Female
# 4                    NaN                   NaN        White
# 5                    NaN                   NaN     NonWhite
# 6                    NaN                   NaN     NonWhite
# 7                    NaN                   NaN     NonWhite
# 8                    NaN                   NaN      Western
# 9                    NaN                   NaN      Eastern
# 10                   NaN                   NaN      Eastern
# 11                   NaN                   NaN      Eastern
# 12                   NaN                   NaN        Other
# 13                   NaN                   NaN        Other
# 14                   NaN                   NaN        Other
# 15                   NaN                   NaN        Other
# 16                   NaN                   NaN       Female
# 17                   NaN                   NaN       Female
# 18                   NaN                   NaN       Female
# 19                   NaN                   NaN       Female
# 20                   NaN                   NaN        White
# 21                   NaN                   NaN     NonWhite
# 22                   NaN                   NaN     NonWhite
# 23                   NaN                   NaN     NonWhite
# 24                   NaN                   NaN      Western
# 25                   NaN                   NaN      Eastern
# 26                   NaN                   NaN      Eastern
# 27                   NaN                   NaN      Eastern
# 28                   NaN                   NaN        Other
# 29                   NaN                   NaN        Other
# 30                   NaN                   NaN        Other
# 31                   NaN                   NaN        Other
# 32                   NaN                   NaN       Female
# 33                   NaN                   NaN       Female
# 34                   NaN                   NaN       Female
# 35                   NaN                   NaN       Female
# 36                   NaN                   NaN        White
# 37                   NaN                   NaN     NonWhite
# 38                   NaN                   NaN     NonWhite
# 39                   NaN                   NaN     NonWhite
# 40                   NaN                   NaN      Western
# 41                   NaN                   NaN      Eastern
# 42                   NaN                   NaN      Eastern
# 43                   NaN                   NaN      Eastern
# 44                   NaN                   NaN        Other
# 45                   NaN                   NaN        Other
# 46                   NaN                   NaN        Other
# 47                   NaN                   NaN        Other

# %%
# ------------------------------
# CONFIG
# ------------------------------

TONE_ORDER = ['Appreciation', 'Constructiveness', 'Clarifications', 'Critique']
IDENTITY_ORDER = [ 'All', 'Undisclosed', 'Disclosed'] # column order
CONFOUNDERS_ORDER = ['gender', 'race', 'region', 'uni_rank']  # row order
CONF_LABELS = {
    'gender': {
        'title': 'Gender (Male/Female)',
        'groups': {'Male': 'Male', 'Female': 'Female'}
    },
    'race': {
        'title': 'Race (White/Non-White)',
        'groups': {'White': 'White', 'NonWhite': 'Non-White'}
    },
    'region': {
        'title': 'Region (West/East)',
        'groups': {'Western': 'West', 'Eastern': 'East'}
    },
    'uni_rank': {
        'title': 'Institution Ranking (Top 100/Other)',
        'groups': {'Top100': 'Top 100', 'Other': 'Other'}
    },
}
# palette for group labels 
CUSTOM_PALETTE = {
    'Male': '#1f77b4', 'Female': '#ff7f0e',
    'White': '#1f77b4', 'NonWhite': '#ff7f0e',
    'Western': '#1f77b4', 'Eastern': '#ff7f0e',
    'Top100': '#1f77b4', 'Other': '#ff7f0e'
}
FALLBACK_COLORS = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728'] 

FIGSIZE = (28, 26)
FONT_SIZE = 16
ANNOT_SIZE = 16
MEAN_LABEL_SIZE = 16
STAR_SIZE = 22

SAVE_FIG = False   # set True to save
OUT_PATH = Path("figures/mannwhitney_12subplots.svg")

# ------------------------------
# HELPERS
# ------------------------------
def annotate_significance(p):
    if pd.isna(p):  return ""
    if p < 0.001:   return "***"
    if p < 0.01:    return "**"
    if p < 0.05:    return "*"
    return ""

def color_for(group):
    if group in CUSTOM_PALETTE:
        return CUSTOM_PALETTE[group]
    i = hash(group) % len(FALLBACK_COLORS)
    return FALLBACK_COLORS[i]

def build_plot_df(results_df, confounder, identity):
    """Return df with one row per bar to plot for a specific confounder+identity."""
    sub = results_df[
        (results_df['Confounder'] == confounder) &
        (results_df['Reviewer Identity'] == identity)
    ].copy()
    display_map = CONF_LABELS.get(confounder, {}).get('groups', {})
    # Each row in sub is one comparison (Group1 vs Group2) for a tone
    rows = []
    for _, r in sub.iterrows():
        rows.append({
            "Tone Category": r["Tone Category"],
            "Group": r["Group 1"],
            "GroupDisp": display_map.get(r["Group 1"], r["Group 1"]),
            "Mean": r["Group 1 Mean"],
            "SE": r.get("Group 1 SE", np.nan),
            "N": r.get("Group 1 Size", np.nan),
            "P-value": r["P-value"],
            "Significance": r["Significance"]
        })
        rows.append({
            "Tone Category": r["Tone Category"],
            "Group": r["Group 2"],
            "GroupDisp": display_map.get(r["Group 2"], r["Group 2"]),
            "Mean": r["Group 2 Mean"],
            "SE": r.get("Group 2 SE", np.nan),
            "N": r.get("Group 2 Size", np.nan),
            "P-value": r["P-value"],
            "Significance": r["Significance"]
        })
    out = pd.DataFrame(rows)

    # stable tone ordering and dropping tones missing entirely
    out = out[out['Tone Category'].isin(TONE_ORDER)]
    out['Tone Category'] = pd.Categorical(out['Tone Category'], categories=TONE_ORDER, ordered=True)
    
    return out.sort_values(['Tone Category', 'GroupDisp'])
def draw_subplot(ax, plot_df, subset_for_sig, confounder, identity):
    # color consistency from raw groups, show display labels in legend.
    map_groups = CONF_LABELS.get(confounder, {}).get('groups', {})

    # keeping the raw order (Group 1 then Group 2) and deriving display order from it
    groups_in_order_raw = []
    for _, r in subset_for_sig.iterrows():
        for g in (r['Group 1'], r['Group 2']):
            if g not in groups_in_order_raw:
                groups_in_order_raw.append(g)

    groups_in_order_disp = [map_groups.get(g, g) for g in groups_in_order_raw]
    palette = {map_groups.get(g, g): color_for(g) for g in groups_in_order_raw}

    sns.barplot(
        data=plot_df, y="Tone Category", x="Mean", hue="GroupDisp",
        order=TONE_ORDER, hue_order=groups_in_order_disp,
        palette=palette, dodge=True, ax=ax, edgecolor='none'
    )

    # Slim bars
    for c in ax.containers:
        for bar in c:
            bar.set_height(0.35)

    # annotations: error bars + mean labels + N labels
    bars = [b for c in ax.containers for b in c]
    x_range = ax.get_xlim()[1] - ax.get_xlim()[0] if ax.get_xlim()[1] != ax.get_xlim()[0] else 1.0
    for bar, (_, row) in zip(bars, plot_df.iterrows()):
        x = bar.get_width()
        y = bar.get_y() + bar.get_height()/2

        if pd.notna(row["SE"]) and row["SE"] > 0:
            ax.errorbar(x=x, y=y, xerr=row["SE"], fmt='none', ecolor='black', elinewidth=1.5, capsize=2.5)

        # Mean-Whitney value 
        ax.text(x + 0.03 * x_range, y, f"{x:.2f}", va='center', ha='left', fontsize=MEAN_LABEL_SIZE)

        # N label 
        if pd.notna(row.get("N", np.nan)):
            ax.text(
                x - 0.3,  # shift left
                y - bar.get_height()/4 + 0.02,
                f"n={int(row['N'])}",
                va='top',
                ha='right',
                fontsize=ANNOT_SIZE,
                color="#FFFFFF"
            )

    # Significance stars
    y_positions = {tone: i for i, tone in enumerate(TONE_ORDER)}
    for tone in TONE_ORDER:
        pair = subset_for_sig[subset_for_sig["Tone Category"] == tone]
        if pair.empty:
            continue
        m1 = pair.iloc[0]["Group 1 Mean"]; m2 = pair.iloc[0]["Group 2 Mean"]
        p  = pair.iloc[0]["P-value"]
        star = annotate_significance(p)
        if star:
            xmax = np.nanmax([m1, m2])
            ax.text(xmax + 0.05 * x_range, y_positions[tone],
                    star, ha='left', va='center', fontsize=STAR_SIZE, fontweight='bold', color='#FF0000')

    # Title
    title_txt = CONF_LABELS.get(confounder, {}).get('title', confounder)
    ax.set_title(f"{title_txt} — {identity}", fontsize=FONT_SIZE+1, pad=8)
    ax.set_xlabel("")
    ax.set_ylabel("")
    ax.grid(axis='y', color='#eee')
    ax.grid(False, axis='x')
    ax.tick_params(axis='both', labelsize=FONT_SIZE)
    ax.legend(title="Group", loc='lower right', fontsize=FONT_SIZE-1,
              title_fontsize=FONT_SIZE-1, frameon=False)


def plot_results_grid(results_df):
    required_cols = {
        'Tone Category','Reviewer Identity','Confounder',
        'Group 1','Group 2',
        'Group 1 Mean','Group 1 SE','Group 1 Size',
        'Group 2 Mean','Group 2 SE','Group 2 Size',
        'P-value'
    }
    missing = required_cols - set(results_df.columns)
    if missing:
        raise ValueError(f"results_df is missing columns: {missing}")

    sns.set_theme(style="whitegrid")
    plt.rcParams.update({'font.size': FONT_SIZE})

    fig, axes = plt.subplots(len(CONFOUNDERS_ORDER), len(IDENTITY_ORDER),
                             figsize=FIGSIZE, sharex=False)
    axes = np.atleast_2d(axes)

    fig.suptitle("Tone Means by Group with SE and Significance (Mann–Whitney)",
                 fontsize=FONT_SIZE+4, y=0.995)

    for i, confounder in enumerate(CONFOUNDERS_ORDER):
        for j, identity in enumerate(IDENTITY_ORDER):
            ax = axes[i, j]
            subset_for_sig = results_df[
                (results_df['Confounder'] == confounder) &
                (results_df['Reviewer Identity'] == identity)
            ].copy()

            if subset_for_sig.empty:
                ax.axis('off')
                ax.set_title(f"{confounder} ({identity}) — no data", fontsize=FONT_SIZE)
                continue

            plot_df = build_plot_df(results_df, confounder, identity)
            draw_subplot(ax, plot_df, subset_for_sig, confounder, identity)

    plt.tight_layout(rect=[0, 0, 1, 0.98])

    if SAVE_FIG:
        OUT_PATH.parent.mkdir(parents=True, exist_ok=True)
        fig.savefig(OUT_PATH, dpi=300, bbox_inches="tight")
        print(f"Saved figure → {OUT_PATH.resolve()}")

    plt.show()

# ------------------------------
# USAGE
# ------------------------------

plot_results_grid(results_ttest)
# Out:
# Saved figure → C:\Users\ms13502\peer_review_project\figures\mannwhitney_12subplots.svg
